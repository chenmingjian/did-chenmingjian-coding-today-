# %%
import tensorflow as tf
from tensorflow import keras

# %%
fashion_mnist = keras.datasets.fashion_mnist
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# %%
x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(10, activation=tf.nn.softmax)
])

# %%
loss = 'sparse_categorical_crossentropy'
optimizer = tf.keras.optimizers.SGD(0.1)

# %%
model.compile(optimizer=optimizer,
                loss=loss,
                metrics=['accuracy'])
model.fit(x_train, y_train, epochs=5, batch_size=256)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.7946 - accuracy: 0.7395
# Epoch 2/5
# 60000/60000 [==============================] - 1s 16us/sample - loss: 0.5737 - accuracy: 0.8108
# Epoch 3/5
# 60000/60000 [==============================] - 1s 16us/sample - loss: 0.5276 - accuracy: 0.8247
# Epoch 4/5
# 60000/60000 [==============================] - 1s 17us/sample - loss: 0.5028 - accuracy: 0.8313
# Epoch 5/5
# 60000/60000 [==============================] - 1s 16us/sample - loss: 0.4877 - accuracy: 0.8360

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print("Test Acc:", test_acc)
# Out:
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================ ...
# Test Acc: 0.8251
